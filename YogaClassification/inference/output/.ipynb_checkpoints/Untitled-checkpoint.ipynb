# %%
import pandas as pd

df = pd.read_csv("analysis.csv")

# %%
df.head()
# Out:
#                 actuals           predicted_1   probs_1  predicted_2   probs_2
# 0  adhomukha_shwanasana  adhomukha_shwanasana  0.995473  trikonasana  0.003960
# 1  adhomukha_shwanasana  adhomukha_shwanasana  0.884925  trikonasana  0.111279
# 2  adhomukha_shwanasana  adhomukha_shwanasana  0.747701  trikonasana  0.237761
# 3  adhomukha_shwanasana  adhomukha_shwanasana  0.990556  trikonasana  0.006914
# 4  adhomukha_shwanasana  adhomukha_shwanasana  0.960575  trikonasana  0.035437

# %%
def highlight(s):
    if s['actuals'] != s['predicted_1'] :
        return ['background-color: yellow']*len(s)
    else:
        return ['background-color: white']*len(s)

# %%
df.style.apply(highlight, axis=1)
# Out:
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# adhomukha_shwanasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# balasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# phalakasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# tadasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# vrikshasana
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/style.py in _repr_html_(self)
#     149     def _repr_html_(self):
#     150         """Hooks into Jupyter notebook rich display system."""
# --> 151         return self.render()
#     152
#     153     @Appender(_shared_docs['to_excel'] % dict(
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/style.py in render(self, **kwargs)
#     444         * table_attributes
#     445         """
# --> 446         self._compute()
#     447         # TODO: namespace all the pandas keys
#     448         d = self._translate()
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/style.py in _compute(self)
#     512         r = self
#     513         for func, args, kwargs in self._todo:
# --> 514             r = func(self)(*args, **kwargs)
#     515         return r
#     516
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#     544                                                        res=result.shape,
#     545                                                        expect=expected_shape))
# --> 546             raise ValueError(msg)
#     547         self._update_ctx(result)
#     548         return self
#
# ValueError: Function <function highlight at 0x7f728fa306a8> returned the wrong shape.
# Result has shape: (317,)
# Expected shape:   (317, 5)

# %%
def highlight_greaterthan(s, column):
    is_max = pd.Series(data=False, index=s.index)
    is_max[column] = s.loc[column] >= threshold
    return ['background-color: yellow' if is_max.any() else '' for v in is_max]


df.style.apply(highlight_greaterthan, column=['C', 'B'], axis=1)
